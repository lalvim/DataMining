# %% [markdown]
# # Unidade [N] — [Tema]
#
# ## [Título do notebook]
#
# **Carga estimada:** [tempo]
# **Pré-requisitos:** [conhecimentos]
#
# > **Pergunta norteadora:** [pergunta que organiza o estudo]

# %% [markdown]
# ## Objetivos de aprendizagem
#
# Ao concluir este notebook, você será capaz de:
#
# - [objetivo observável 1];
# - [objetivo observável 2];
# - [objetivo observável 3].

# %%
# Importações e configuração
RANDOM_STATE = 42

# %% [markdown]
# ## Motivação
#
# [Apresente o problema, o contexto e o resultado esperado.]

# %% [markdown]
# ## Fundamentos
#
# [Defina conceitos, hipóteses e notação.]
#
# $$
# [fórmula]
# $$

# %% [markdown]
# ## Exemplo guiado
#
# [Inclua um exemplo pequeno antes da aplicação completa.]

# %%
# Implemente o exemplo guiado.

# %% [markdown]
# ## Aplicação com dados
#
# [Descreva dados, procedimento e resultado esperado.]

# %% [markdown]
# > **Verifique seu entendimento:** [pergunta conceitual]
#
# > **Exercício:** [atividade e produto esperado]

# %% [markdown]
# ## Síntese
#
# - [conclusão 1];
# - [conclusão 2];
# - [limitação ou conexão futura].
#
# ## Referências
#
# - [referência completa].
